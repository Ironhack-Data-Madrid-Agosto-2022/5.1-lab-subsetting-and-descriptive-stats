# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.
#
#  En este desafío, utilizaremos el archivo Temp_States.csv.¶ Primero impórtelo a un marco de datos llamado temp.

# %%
# your answer here

temp = pd.read_csv('Temp_States.csv')
temp.head()
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444

# %% [markdown]
# #### Print `temp`

# %%
print(temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.
#
#  Explore los tipos de datos del marco de datos Temp. ¿Qué tipo de datos tenemos? Comenta tu resultado.

# %%
temp.info()

''' tenemos una tabla de 7 filas y 3 columnas
Las columnas ciudad y estado, son str ; y la columna temperatura es un float'''
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         7 non-null      object
#  1   State        7 non-null      object
#  2   Temperature  7 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# #### Select the rows where state is New York

# %%
new_york = temp.loc[:,'State'] == 'New York'
temp_new_york = temp.loc[new_york]

temp_new_york
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
temp_new_york.mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius
#
#  Queremos conocer ciudades y estados con una temperatura superior a 15 grados Celcius

# %%
temp_15 = temp[temp.Temperature > 15]
temp_15
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius
#
#  Ahora, devuelva solo las ciudades que tienen una temperatura superior a 15 grados Celcius

# %%
temp_15 = temp[temp.Temperature > 15]
temp_15['City'].unique()
# Out:
# array(['NYC', 'Hartford', 'Treton', 'Newark'], dtype=object)

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*
#
# Queremos saber qué ciudades tienen una temperatura superior a 15 grados centígrados y inferior a 20 grados centígrados Sugerencia: Primero escriba la condición y luego seleccione las filas

# %%
# your answer here
temp_15_20 = temp[(temp.Temperature > 15) & (temp.Temperature <20)]
temp_15_20

#reqd_stocks = stocks_df[(stocks_df.Sector == "Technology") & (stocks_df.Price <500)]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*
#
# Encuentre la media y la desviación estándar de la temperatura de cada estado.¶
# Sugerencia: use funciones de la lección de manipulación de datos

# %%
# your answer here
aaa = temp.iloc[:, 1 : 3]
aaa.mean()

''' pendiente de terinar'''
# Out:
# ' pendiente de terinar'

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
employee = pd.read_csv('employee.csv')
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
employee.info()

''' tenemos una tabla de 9 filas y 6 columnas
Las primeras columnas son STR, y las dos ultimas (Año y Salario) son INT''';
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        9 non-null      object
#  1   Department  9 non-null      object
#  2   Education   9 non-null      object
#  3   Gender      9 non-null      object
#  4   Title       9 non-null      object
#  5   Years       9 non-null      int64
#  6   Salary      9 non-null      int64
# dtypes: int64(2), object(5)
# memory usage: 632.0+ bytes

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?
#
#  Muestre visualmente la distribución de frecuencia ( histograma ) del conjunto de datos del empleado. En pocas palabras, ¿describe estos histogramas?

# %%
# your answer here

# %% [markdown]
# #### What's the average salary in this company?

# %%
employee['Salary'].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
employee['Salary'].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
employee['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?
#
#  ¿Quiénes son los empleados con el salario más bajo?

# %%
employee.Name[employee.Salary == employee['Salary'].min()].unique()
# Out:
# array(['Maria', 'David'], dtype=object)

# %% [markdown]
# #### Could you give all the information about an employee called David?
#
#  ¿Podría dar toda la información sobre un empleado llamado David?

# %%
# your answer here
employee[employee.Name == 'David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?
#
#  #### Podrías dar solo el salario de David?

# %%
# your answer here
employee.Salary[employee.Name == 'David'].unique()
# Out:
# array([30])

# %% [markdown]
# #### Print all the rows where job title is associate
#
#  Imprima todas las filas donde el título del trabajo es asociado

# %%
employee[employee.Title == 'associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways
#
#
# Imprima las primeras 3 filas de su marco de datos #####
#  Consejo: Hay 2 formas de hacerlo. Hazlo en ambos sentidos

# %%
# your answer here- 1 method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?
#
# Encuentra los empleados cuyo título es asociado y el salario superior a 55?

# %%
# your answer here
employee_55 = employee[(employee.Title == "associate") & (employee.Salary >55)]
employee_55
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?
#
#  Agrupe a los empleados en función de su número de años de empleo. ¿Cuáles son los salarios promedio en cada grupo?

# %%
employee.groupby(['Years']).Salary.mean()
# Out:
# Years
# 1    35.000000
# 2    38.333333
# 3    55.000000
# 4    35.000000
# 7    60.000000
# 8    70.000000
# Name: Salary, dtype: float64

# %% [markdown]
# ####  What is the average Salary per title?
#
#  ¿Cuál es el salario promedio por título?

# %%
employee.groupby(['Title']).Salary.mean()
# Out:
# Title
# VP           70.000000
# analyst      32.500000
# associate    56.666667
# Name: Salary, dtype: float64

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`
#
#  #### Mostrar un resumen visual de los datos usando boxplot. ¿Cuáles son los cuartiles primero y tercero? Comenta tus resultados. ##### * Sugerencia: Cuántiles vs Cuartiles * ##### - `En Probabilidad y Estadísticas, los cuantiles son puntos de corte que dividen el rango de una distribución de probabilidad en intervalos continuos con igual probabilidad. Cuando la división es en cuatro partes, los valores de la variación correspondientes al 25%, 50% y 75% de la distribución total se denominan cuartiles.``

# %%
import pylab as plt
import seaborn as sns

# %%
# draw boxplot here
sns.boxplot(data=employee['Salary']);

# %%
# print first quartile here
np.quantile(employee['Salary'], 0.25)
# Out:
# 35.0

# %%
# print third quartile here
np.quantile(employee['Salary'], 0.75)
# Out:
# 60.0

# %% [markdown]
# #### Is the mean salary per gender different?
#
#  ¿Es diferente el salario medio por género?

# %%
# your answer here

employee.groupby(['Gender']).Salary.mean()
# Out:
# Gender
# F    47.5
# M    50.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson
#
#  #### Encuentre el mínimo, la media y el máximo de todas las columnas numéricas para cada departamento.  ##### Sugerencia: Use funciones de la lección de Manipulación de datos

# %%
print(employee.groupby(['Department']).Salary.mean())
print(employee.groupby(['Department']).Years.mean())
print(employee.groupby(['Department']).Salary.min())
print(employee.groupby(['Department']).Years.min())
print(employee.groupby(['Department']).Salary.max())
print(employee.groupby(['Department']).Years.max())
# Out:
# Department
# HR       45.00
# IT       48.75
# Sales    55.00
# Name: Salary, dtype: float64
# Department
# HR       4.666667
# IT       4.500000
# Sales    2.500000
# Name: Years, dtype: float64
# Department
# HR       30
# IT       30
# Sales    55
# Name: Salary, dtype: int64
# Department
# HR       2
# IT       1
# Sales    2
# Name: Years, dtype: int64
# Department
# HR       70
# IT       70
# Sales    55
# Name: Salary, dtype: int64
# Department
# HR       8
# IT       8
# Sales    3
# Name: Years, dtype: int64

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
orders = pd.read_csv('Orders.csv')
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results
#
#  #### Explore su conjunto de datos mirando los tipos de datos y las estadísticas resumidas. Comenta tus resultados

# %%
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %%
# your answer here

# %% [markdown]
# ####  What is the average Purchase Price?
#
#  ¿Cuál es el precio promedio de compra?

# %%
orders['UnitPrice'].mean()
# Out:
# 3.116174480549152

# %% [markdown]
# #### What were the highest and lowest purchase prices?
#
#  #### Cuáles fueron los precios de compra más altos y más bajos?

# %%
orders['UnitPrice'].max()
# Out:
# 8142.75

# %%
orders['UnitPrice'].min()
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers we have in Spain
#
#  #### Seleccione todos los clientes que tenemos en España

# %%
orders_spain = orders[orders['Country']=="Spain"]

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()
#
#  #### Cuántos clientes tenemos en España? ##### Sugerencia: Use value_counts ( )

# %%
orders_spain['CustomerID'].value_counts()
# Out:
# 12540    478
# 12484    346
# 12539    273
# 17097    211
# 12597    206
# 12502    147
# 12556    121
# 12546     69
# 12462     62
# 12354     58
# 12550     57
# 12541     52
# 12545     50
# 12455     48
# 12421     45
# 12510     33
# 12557     33
# 12596     27
# 12417     23
# 12507     22
# 12448     22
# 12538     21
# 12544     19
# 12454     15
# 12442     12
# 12551     10
# 12450      8
# 12547      8
# 12548      5
# 12445      4
# Name: CustomerID, dtype: int64

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?
#
#  #### Selecciona todos los clientes que han comprado más de 50 artículos ?

# %%
orders_50 = orders[orders['Quantity']>50]
orders_50['CustomerID'].value_counts()
# Out:
# 14646    1266
# 12415     454
# 17511     431
# 13694     370
# 14156     309
#          ...
# 15306       1
# 17948       1
# 16813       1
# 16511       1
# 16446       1
# Name: CustomerID, Length: 1301, dtype: int64

# %% [markdown]
# #### Select orders from Spain that are above 50 items
#
#  Seleccione pedidos de España que estén por encima de 50 artículos

# %%
orders_spain_50 = orders_spain[orders_spain['Quantity']>50]
orders_spain_50
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders

# %%
orders[orders['UnitPrice']==0]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions
#
#  #### Seleccione todos los pedidos que son 'bolsa de almuerzo'
#  #### Sugerencia: Use funciones de str

# %%
orders_lunch = orders[orders.Description.str.contains('lunch bag')]

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
orders_lunch[orders_lunch['year']==2011]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.
#
#  Mostrar la distribución de frecuencia de la cantidad gastada en España.

# %%
# your answer here

# %% [markdown]
# #### Select all orders made in the month of August

# %%
orders_8 = orders[orders['month']==8]

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()
#
#  Seleccione cuántos pedidos hacen los países en el mes de agosto¶ Sugerencia: Use value_counts ( )

# %%
print(orders_8.Country.value_counts( ))
# Out:
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: Country, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country
#
#  #### Cuál es la cantidad promedio de dinero gastado por país?

# %%
print(orders.groupby(['Country']).amount_spent.mean())
# Out:
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# ...

# %% [markdown]
# #### What's the most expensive item?
#
#  ¿Cuál es el artículo más caro?

# %%
expensive = orders.loc[:,'UnitPrice'] == orders['UnitPrice'].max()
expensive2 = orders.loc[expensive]

expensive2
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour Description  \
# 118352      173382     551697      POST  2011      5    2    13     postage
#
#         Quantity          InvoiceDate  UnitPrice  CustomerID         Country  \
# 118352         1  2011-05-03 13:46:00    8142.75       16029  United Kingdom
#
#         amount_spent
# 118352       8142.75

# %% [markdown]
# #### What was the average amount spent per year ?
#
#  #### Cuál fue la cantidad promedio gastada por año ?

# %%
print(orders.groupby(['year']).amount_spent.mean())
# Out:
# year
# 2010    21.892733
# 2011    22.430074
# Name: amount_spent, dtype: float64
